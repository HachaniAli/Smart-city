# %%
# Importation de librairies

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Importation du fichier excel

df = pd.ExcelFile("Unicorn.xlsx") # Load spreadsheet
df = df.parse('Unicorns', skiprows=2)

# %%
# Keep needed columns

df = df[['Company', 'Valuation ($B) ', 'Date Added', 'Country',
       'Category', 'Select Investors']]
df.columns
# Out:
# Index(['Company', 'Valuation ($B) ', 'Date Added', 'Country', 'Category',
#        'Select Investors'],
#       dtype='object')

# %%
df.head(5)
# Out:
#       Company  Valuation ($B)  Date Added        Country  \
# 0   Bytedance            140.0 2017-04-07          China
# 1      SpaceX            100.3 2012-12-01  United States
# 2      Stripe             95.0 2014-01-23  United States
# 3      Klarna             45.6 2011-12-12         Sweden
# 4  Epic Games             42.0 2018-10-26  United States
#
#                   Category                                   Select Investors
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures

# %%
df.rename(columns={"Valuation ($B) ": "Valuation", "Date Added": "Date_Added"}, inplace=True)

# %%
df.head(5)
# Out:
#       Company  Valuation Date_Added        Country                 Category  \
# 0   Bytedance      140.0 2017-04-07          China  Artificial intelligence
# 1      SpaceX      100.3 2012-12-01  United States                    Other
# 2      Stripe       95.0 2014-01-23  United States                  Fintech
# 3      Klarna       45.6 2011-12-12         Sweden                  Fintech
# 4  Epic Games       42.0 2018-10-26  United States                    Other
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2        Khosla Ventures, LowercaseCapital, capitalG
# 3  Institutional Venture Partners, Sequoia Capita...
# 4              Tencent Holdings, KKR, Smash Ventures

# %%
# Number ok countries
NC =df['Country'].str.count(',').add(1).groupby(df.Country).sum()

# %%
NC.sort_values(ascending=False)
NC.column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/tm/ym72fqh16_7by4fpzh7vcv_80000gn/T/ipykernel_3956/684295005.py in <module>
#       1 NC.sort_values(ascending=False)
# ----> 2 NC.column
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'column'

# %%
fig, ax = plt.subplots()
ax.bar(NC)
ax.set_title('hist countries')
ax.set_xlabel('Country')
ax.set_ylabel('Number of projects')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/tm/ym72fqh16_7by4fpzh7vcv_80000gn/T/ipykernel_3956/1898522911.py in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax[0].bar(NC)
#       3 ax[0].set_title('hist countries')
#       4 ax[0].set_xlabel('Country')
#       5 ax[0].set_ylabel('Number of projects')
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %% [markdown]
# - Variation de la valuation par rapport a la date
# - distribution de la valuation

# %%
ts = df[['Date_Added', 'Valuation']]

# %%
fig, ax = plt.subplots(1,2)
ax[0].hist(ts['Valuation'])
ax[0].set_title('distribution de valuation')
ax[0].set_xlabel('number of companies')
ax[0].set_ylabel('B $')

ax[1].scatter(ts['Date_Added'],ts['Valuation'])
ax[1].set_ylabel('B $')
# Out:
# Text(0, 0.5, 'B $')

# %%
df.columns
# Out:
# Index(['Company', 'Valuation ($B) ', 'Date_Added', 'Country', 'Category',
#        'Select Investors'],
#       dtype='object')

# %%
df.dtypes

# %%
df['Select Investors'] = df['Select Investors'].astype('str')

# %% [markdown]
# # For loop to get all the investors

# %%
investors = []

for i in range(len(df)):
    for j in range(len(df.loc[i, 'Select Investors'].split(','))):
        investors.append(df.loc[i, 'Select Investors'].split(',')[j])

output = []
for x in investors:
    if x not in output:
        output.append(x)

investors = output

# %%
type(investors)
# Out:
# list

# %%
investors[i]
# Out:
# ' CMC Capital Partners'

# %%
my_dict = {}
for i in range(len(investors)):
    my_dict[investors[i]] = 0

# %%
for i in range(len(df)):
    for j in range(len(df.loc[i, 'Select Investors'].split(','))):
        for key in my_dict:
            if df.loc[i, 'Select Investors'].split(',')[j] == key:
                my_dict[key] += 1

# %%
my_dict
# Out:
# {'Sequoia Capital China': 29,
#  ' SIG Asia Investments': 3,
#  ' Sina Weibo': 2,
#  ' Softbank Group': 8,
#  'Founders Fund': 4,
#  ' Draper Fisher Jurvetson': 1,
#  ' Rothenberg Ventures': 1,
#  'Khosla Ventures': 11,
#  ' LowercaseCapital': 1,
#  ' capitalG': 6,
#  'Institutional Venture Partners': 3,
#  ' Sequoia Capital': 27,
#  ' General Atlantic': 18,
#  'Tencent Holdings': 11,
#  ' KKR': 3,
#  ' Smash Ventures': 1,
#  ' Blackbird Ventures': 2,
#  ' Matrix Partners': 4,
#  'Tiger Global Management': 14,
#  ' Insight Partners': 21,
#  ' DST Global': 15,
#  ' Kleiner Perkins Caufield & Byers': 14,
#  ' Collaborative Fund': 1,
#  'Andreessen Horowitz': 25,
#  ' New Enterprise Associates': 7,
#  ' Battery Ventures': 13,
#  'index Ventures': 1,
#  ' Ribbit Capital': 7,
#  'Sequoia Capital': 16,
#  ' Thoma Bravo': 3,
#  ' Softbank': 3,
#  'Forerunner Ventures': 2,
#  ' Crosslink Capital': 2,
#  ' Homebrew': 2,
#  ' Lightspeed India Partners': 2,
#  ' Sequoia Capital India': 15,
#  'GGV Capital': 7,
#  ' ZhenFund': 7,
#  ' Tencent': 4,
#  'Hillhouse Capital Management': 3,
#  ' Boyu Capital': 3,
#  ' Sequoia Capital China': 17,
#  'SoftBank Group': 12,
#  ' Andreessen Horowitz': 18,
#  ' Temasek Holdings': 4,
#  'Accel': 27,
#  ' AltaIR Capital': 3,
#  ' Technology Crossover Ventures': 5,
#  ' Warbug Pincus': 1,
#  ' IDG Capital': 16,
#  'Accel Partners': 5,
#  ' Shunwei Capital Partners': 4,
#  'IDG Capital': 6,
#  ' Venture51': 1,
#  ' Lightspeed Venture Partners': 18,
#  ' Longfor Capitalm': 1,
#  ' Gaorong Capital': 3,
#  ' Anthos Capital': 2,
#  'New Enterprise Associates': 14,
#  ' Spar Capital': 1,
#  ' Index Ventures': 16,
#  ' Thirty Five Ventures': 1,
#  ' Sound Ventures': 5,
#  'General Catalyst': 10,
#  ' Institutional Venture Partners': 7,
#  ' Breyer Capital': 1,
#  ' F-Prime Capital': 3,
#  ' Venrock': 5,
#  ' Forerunner Ventures': 2,
#  'DST Global': 7,
#  ' Greenoaks Capital Management': 3,
#  'Coatue Management': 5,
#  'Vickers Venture Partners': 1,
#  ' IKEA GreenTech': 1,
#  ' BDT Capital Partners': 1,
#  ' Davidson Kempner Capital Management': 1,
#  'Caffeinated Capital': 2,
#  ' CRV': 7,
#  ' Founder Collective': 1,
#  'LTW Capital': 1,
#  ' Legend Capital': 2,
#  ' Qualcomm Ventures': 6,
#  'Aviation Industry Corporation of China': 1,
#  ' Essence Financial': 1,
#  ' Jiangsu Sha Steel Group': 1,
#  ' 83North': 3,
#  'Activant Capital': 1,
#  ' Tribe Capital': 2,
#  ' Hillhouse Capital Management': 5,
#  ' Yunfeng Capital': 2,
#  'Accel India': 1,
#  ' SAIF Partners': 1,
#  ' Norwest Venture Partners': 8,
#  'General Catalyst Partners': 1,
#  ' Google Ventures': 18,
#  'Y Combinator': 6,
#  ' Coatue Management': 16,
#  'DJF': 1,
#  ' Salesforce Ventures': 5,
#  ' Storm Ventures': 3,
#  'MindWorks Ventures': 1,
#  ' Xiang He Capital': 2,
#  'Index Ventures': 14,
#  ' Draft Ventures': 1,
#  ' Felicis Ventures': 3,
#  ' Greylock Partners': 7,
#  'Upper90': 1,
#  ' RiverPark Ventures': 2,
#  ' Advent International': 3,
#  'Ribbit Capital': 1,
#  'Lightspeed India Partners': 2,
#  'KKR': 6,
#  ' ES Ventures': 1,
#  ' North Bridge Growth Equity': 1,
#  'Bessemer Venture Partners': 10,
#  ' ICONIQ Capital': 8,
#  ' Tencent Investment': 1,
#  ' BA Capital': 1,
#  'Redalpine Venture Partners': 1,
#  ' Earlybird Venture Capital': 2,
#  ' Valar Ventures': 6,
#  'Summit Partners': 3,
#  ' Accel': 30,
#  ' Astral Capital': 1,
#  'Vattenfall': 1,
#  ' Volkswagen Group': 1,
#  ' Goldman Sachs': 12,
#  ' Nor-Cal Invest': 1,
#  ' TPG Growth': 2,
#  ' GX Capital': 1,
#  'Nintendo': 1,
#  ' Google': 2,
#  ' Pokemon Company International': 1,
#  ' Spark Capital': 5,
#  'Target Global': 2,
#  ' General Catalyst': 23,
#  ' Durable Capital Partners': 2,
#  ' SoftBank Group': 19,
#  ' Mountain Nazca': 1,
#  'BOLDstart Ventures': 3,
#  'Didi Chuxing': 1,
#  ' Diamler': 1,
#  ' TMT Investments': 1,
#  '01 Advisors': 1,
#  ' Zeev Ventures': 3,
#  ' Group 11': 1,
#  'Sutter Hill Ventures': 1,
#  ' Liberty Global Ventures': 1,
#  ' T. Rowe Associates': 1,
#  ' Lightbank': 1,
#  'Kaalari Capital': 1,
#  ' Tencent Holdings': 17,
#  ' Steadview Capital': 1,
#  'Tenaya Capital': 1,
#  ' Stripes Group': 2,
#  'Sixth Street Partners': 1,
#  ' OrbiMed Advisors': 2,
#  ' Highland Capital Management': 1,
#  ' Northzone Ventures': 5,
#  'Union Square Ventures': 5,
#  'Lightspeed Venture Partners': 12,
#  ' Social Capital': 2,
#  'Sequoia Capital India': 11,
#  ' Tiger Global Management': 33,
#  ' Matrix Partners India': 3,
#  ' Revo Capital': 1,
#  'Menlo Ventures': 4,
#  ' Union Square Ventures': 1,
#  ' Y Combinator': 12,
#  'Volkswagen Group': 1,
#  ' Ford Autonomous Vehicles': 1,
#  'Norwest Venture Partners': 5,
#  ' Next World Capital': 2,
#  ' Wing Venture Capital': 2,
#  'Morgan Creek Digital': 1,
#  ' Marcy Venture Partners': 1,
#  ' 10T Fund': 1,
#  'Tencent': 3,
#  ' Morningside Group': 1,
#  'Benchmark': 5,
#  'General Atlantic': 9,
#  'Slack Fund': 1,
#  ' Skip Capital': 1,
#  ' Warburg Pincus': 8,
#  'TA Associates': 1,
#  ' GS Growth': 4,
#  'Initialized Capital': 5,
#  'Technology Crossover Ventures': 4,
#  ' Accomplice': 1,
#  ' IA Ventures': 3,
#  'Global Founders Capital': 7,
#  ' Nortzone Ventures': 1,
#  ' Picus Capital': 1,
#  ' VY Capital': 1,
#  'Atomico': 2,
#  'Thrive Capital': 8,
#  ' Benchmark': 5,
#  ' MenloVentures': 1,
#  'Barter Ventures': 1,
#  'Warmsun Holding': 1,
#  ' IDG Capital Partners': 2,
#  'Pine Brook': 1,
#  ' American Express Ventures': 4,
#  'Insight Partners': 20,
#  'BlackRock': 2,
#  ' Blackstone': 5,
#  ' UBS': 1,
#  'NextView Ventures': 2,
#  ' Eniac Ventures': 2,
#  'Greylock Partners': 7,
#  ' Providence Ventures': 1,
#  'Alibaba Group': 4,
#  ' Borui Capital': 1,
#  ' Baidu': 4,
#  ' Huasheng Capital': 1,
#  ' A&E Television Networks': 1,
#  ' Maverick Ventures': 1,
#  ' Redpoint Ventures': 7,
#  'Battery Ventures': 1,
#  'Aglae Ventures': 2,
#  ' Eurazeo': 4,
#  ' Daphni': 2,
#  'Nexus Venture Partners': 3,
#  'Matrix Partners': 3,
#  'Runa Capital': 1,
#  ' Acton Capital Partners': 1,
#  ' Point Nine Capital': 1,
#  ' DCM Ventures': 8,
#  'Founders Fund. Accel': 1,
#  ' Creandum': 3,
#  ' Redpoint e.ventures': 1,
#  ' Lakestar': 3,
#  'Venrock': 4,
#  'Kaszek Ventures': 5,
#  'Credit Suisse': 1,
#  'China Life Insurance': 1,
#  ' China Development Bank Capital': 1,
#  ' CITIC Securities International': 1,
#  'Clermont Group': 1,
#  ' Coltrane Asset Management': 1,
#  ' Toscafund Asset Management': 1,
#  'Ant Financial Services Group': 2,
#  ' GGV Capital': 7,
#  ' Linear Venture': 5,
#  ' Morningside Venture Capital': 2,
#  'Baidu Capital': 1,
#  'Eight Roads Ventures': 2,
#  ' Greycroft': 7,
#  ' Ignition Partners': 3,
#  ' Andalusian Capital Partners': 1,
#  ' SignalFire': 2,
#  ' 3i Group': 1,
#  ' Huagai Capital': 1,
#  'Google Ventures': 6,
#  ' FirstMark Capital': 4,
#  'Walden International': 1,
#  ' Intel Capital': 3,
#  'Matrix Partners India': 1,
#  ' Falcon Edge Capital': 2,
#  ' LeapFrog Investments': 1,
#  'Alven Capital': 2,
#  'Venture Highway': 1,
#  ' Prosus Ventures': 5,
#  ' Amadeus Capital Partners': 2,
#  ' Quona Capital': 1,
#  'Oak HC/FT Partners': 2,
#  ' Artis Ventures': 1,
#  ' WestCap Group': 2,
#  'China Grand Prosperity Investment': 2,
#  ' Silk Road Huacheng': 1,
#  ' Oriza Equity Investment': 1,
#  'Threshold Ventures': 2,
#  'Creandum': 1,
#  ' Founders': 1,
#  ' Kinnevik': 2,
#  ' Founders Fund': 12,
#  ' Revolution Ventures': 1,
#  ' T. Rowe Price': 3,
#  ' Viking Global Investors': 2,
#  'Telling Telecommunication Holding Co.': 1,
#  ' Alibaba Group': 6,
#  ' Burda Principal Investments': 1,
#  ' Sinovation Ventures': 1,
#  'Passion Capital': 2,
#  ' Thrive Capital': 8,
#  ' Orange Digital Ventures': 1,
#  'Two Sigma Ventures': 2,
#  ' Flint Capital': 2,
#  ' Commerce Ventures': 4,
#  'CDH Investments': 1,
#  ' Goldstone Investments': 1,
#  ' Qiming Venture Partners': 7,
#  'Mayfield Fund': 3,
#  ' M12': 6,
#  ' Trinity Ventures': 2,
#  ' Khosla Ventures': 8,
#  ' Geodesic Capital': 1,
#  'Addition': 1,
#  ' Benhcmark': 1,
#  'Playground Global': 2,
#  ' Bond': 4,
#  'Vista Equity Partners': 2,
#  ' Wincove': 1,
#  ' TDR Capital': 1,
#  'Speedinvest': 2,
#  ' Uniqa Ventures': 2,
#  ' Comcast Ventures': 4,
#  'Formation 8': 1,
#  ' Russia-China Investment Fund': 1,
#  ' Foxconn Technology Company': 1,
#  ' Foundation Capital': 5,
#  ' Horizons Ventures': 2,
#  ' Starr Investment Holdings': 1,
#  'Zeev Ventures': 4,
#  ' TLV Partners': 1,
#  'Blackrock': 2,
#  ' Kleiner Perkins Caulfield & Byers': 1,
#  'Drive Capital': 1,
#  ' Ascension Ventures': 1,
#  'Georgian Partners': 2,
#  ' Craft Ventures': 1,
#  'Dragoneer Investment Group': 2,
#  ' Hellman & Friedman': 1,
#  ' JMI Equity': 1,
#  ' Bessemer Venture Partners': 11,
#  ' Threshold Ventures': 2,
#  ' TQ Ventures': 1,
#  ' Aleph': 5,
#  ' Bond Capital': 1,
#  'China Health Industry Investment Fund': 1,
#  ' China Renaissance': 1,
#  ' and Sequoia Capital China': 1,
#  'D1 Capital Partners': 1,
#  ' Stripe': 1,
#  ' New Leaf Venture Partners': 1,
#  ' Charter Venture Capital': 1,
#  ' Atomico': 5,
#  ' ICONIQ Growth': 2,
#  'Casa Verde Capital': 1,
#  ' Gron Ventures': 1,
#  ' Thrity Five Ventures': 1,
#  'Blackstone': 2,
#  ' B Capital Group': 1,
#  ' Dell Technologies Capital': 4,
#  'Upfront Ventures': 2,
#  ' Webb Investment Network': 1,
#  ' D1 Capital Partners': 4,
#  ' New Era Ventures': 1,
#  'India Quotient': 1,
#  ' Elevation Capital': 3,
#  'Qualcomm Ventures': 6,
#  ' Samsung Ventures': 2,
#  ' Silver Lake': 2,
#  'Breakthrough Energy Ventures': 1,
#  ' Capricorn Investment Group': 1,
#  ' Valor Equity Partners': 1,
#  'NewView Capital': 1,
#  ' Maveron': 2,
#  ' Ridge Ventures': 1,
#  ' Lux Capital': 3,
#  ' Promus Ventures': 1,
#  ' Two Sigma Ventures': 2,
#  'Silver Lake': 1,
#  'EQT Partners': 2,
#  'Activant Capital Group': 1,
#  ' Alaska Permanent Fund': 1,
#  ' Baillie Gifford & Co.': 3,
#  'Kuang-Chi': 1,
#  'Elaia Partners': 1,
#  ' Felix Capital': 3,
#  'Airbus Ventures': 1,
#  'Fairfax Financial Holdings': 1,
#  ' A91 Partners': 1,
#  ' TVS Capital': 1,
#  'Madrona Venture Group': 4,
#  ' Shasta Ventures': 2,
#  'First Round Capital': 1,
#  'Kleiner Perkins Caufield & Byers': 6,
#  ' True Ventures': 1,
#  'DN Capital': 1,
#  ' Left Lane Capital': 2,
#  ' HCA Healthcare': 1,
#  'WestCap Group': 1,
#  ' Caisse de depot et placement du Quebec': 1,
#  'DFJ Growth Fund': 1,
#  ' Addition': 1,
#  'Blume Ventures': 1,
#  ' Nexus Venture Partners': 4,
#  ' Kalaari Capital': 2,
#  'China Environmental Protection Industry': 1,
#  ' China Fortune Ocean': 1,
#  ' Vertex Ventures': 2,
#  'Oriza Holdings': 1,
#  ' Guangdong Technology Financial Group': 1,
#  'Geely': 1,
#  ' China State Capital Venture Capital Fund': 1,
#  ' Sutter Hill Ventures': 1,
#  'Greycroft': 3,
#  ' Sands Capital': 3,
#  ' Revolution Growth': 2,
#  '83North': 1,
#  ' Pitango Venture Capital': 4,
#  'Moore Strategic Ventures': 1,
#  'Atop Capital': 1,
#  ' IDInvest Partners': 4,
#  ' Lerer Hippeau': 3,
#  ' Kenetic Capital': 1,
#  'Alibaba Pictures Group': 1,
#  'Tiger Global': 1,
#  ' Google Capital': 1,
#  'Bloomberg Beta': 1,
#  ' First Round Capital': 2,
#  'M12': 1,
#  ' WestBridge Capital': 1,
#  ' Cocnord Health Partners': 1,
#  ' Alliance Consumer Growth': 1,
#  ' Imaginary Ventures': 1,
#  ' Bertelsmann India Investments': 2,
#  'AME Cloud Ventures': 1,
#  ' Future Perfect Ventures': 1,
#  ' Blockchain Capital': 2,
#  'Third Point': 1,
#  ' Electric Capital': 1,
#  ' Coinbase Ventures': 4,
#  'Shunwei Capital Partners': 4,
#  ' Addor Capital': 1,
#  ' New Horizon Capital': 2,
#  ' Franklin Templeton': 2,
#  ' BlackRock': 8,
#  ' Microsoft ScaleUp': 1,
#  'Susquehanna Growth Equity': 1,
#  ' Citi Ventures': 4,
#  'Falcon Edge Capital': 1,
#  ' Omidyar Network': 2,
#  ' Atlantic Food Labs': 1,
#  'Iconiq Capital': 1,
#  ' East Ventures': 1,
#  ' Expedia Inc.': 1,
#  'Morningside Ventures': 2,
#  ' CreditEase Fintech Investment Fund': 1,
#  'CPP Investment Board': 1,
#  ' Digital Currency Group': 1,
#  'Jackson Square Ventures': 3,
#  'Times Internet': 1,
#  'Holtzbrinck Ventures': 1,
#  ' Unternehmertum Venture Capital': 1,
#  'Cambridge Innovation Capital': 1,
#  ' LGT Capital Partners': 1,
#  ' Escala Capital': 1,
#  'Matrix Partners China': 5,
#  ' Bright Venture Capita': 1,
#  ' Shenzhen Capital Group': 2,
#  ' Temasek': 6,
#  ' PayPal Ventures': 3,
#  ' Summit Partners': 4,
#  'Artiman Ventures': 1,
#  ' Plug and Play Ventures': 1,
#  'Sequoia Capital Israel': 1,
#  ' Scale Venture Partners': 5,
#  'ICONIQ Capital': 1,
#  ' OpenView Venture Partners': 2,
#  'ConsenSys Ventures': 1,
#  ' PUC': 1,
#  'Capital One Growth Ventures': 1,
#  ' OMERS Ventures': 4,
#  'Uniion Square Ventures': 1,
#  ' Lightspeed Venture Capital': 1,
#  'Silversmith Capital Partners': 1,
#  ' Susquehanna Growth Equity': 2,
#  'Spectrum Equity': 1,
#  ' Grayhawk Capital': 1,
#  'Brookfield Asset Management': 1,
#  ' Data Collective': 3,
#  'Uncork Capital': 1,
#  ' Bloomberg Beta': 1,
#  'Balderton Capital': 2,
#  ' Lead Edge Capital': 1,
#  'Fabric Ventures': 1,
#  ' 500 Global': 1,
#  ' Standard Crypto': 1,
#  ' Jump Capital': 5,
#  ' BMO Capital': 1,
#  ' Schonfeld Strategic Advisors': 1,
#  'Bnk To The Future': 1,
#  ' Trammell Ventures': 1,
#  ' SBI Investment': 2,
#  'Grab': 1,
#  ' Tokopedia': 1,
#  ' Tokyo Century Corporation': 1,
#  ' Quantum Energy Partners': 1,
#  ' Bedrock Capital': 1,
#  'Monashees+': 1,
#  ' QED Investors': 5,
#  ' BEENEXT': 2,
#  'Point72 Ventures': 2,
#  ' Route 66 Ventures': 1,
#  'Mubadala Capital': 1,
#  ' Blue Lake Capital': 1,
#  'Goodwater Capital': 4,
#  ' iFly': 1,
#  ' XVC Venture Capital': 2,
#  'Highland Europe': 1,
#  ' Canaan Partners': 4,
#  'Dell Technologies Capital': 1,
#  'Data Collective': 1,
#  ' Formation 8': 2,
#  ' General Catalyst Partners': 1,
#  ' Javelin Venture Partners': 1,
#  'Makers Fund': 1,
#  ' Inova Ventures Participacees': 1,
#  ' Vintage Investment Partners': 2,
#  'HD Capital': 1,
#  ' Qihoo 360 Technology': 1,
#  ' China Fortune Land Development': 1,
#  'Notion Capital': 1,
#  ' Scentan Ventures': 1,
#  ' Kite Ventures': 1,
#  'Goldman Sachs Asset Management': 3,
#  'Emergence Capital Partners': 1,
#  ' 8VC': 2,
#  ' Chicago Ventures': 2,
#  'Redpoint Ventures': 3,
#  ' Goldcrest Capital': 1,
#  'Foundry Group': 2,
#  'Contour Venture Partners': 1,
#  ' Core Capital Partners': 1,
#  ' Jackson Square Ventures': 1,
#  ' Liberty Gloval Ventures': 1,
#  ' Bain Capital Ventures': 7,
#  ' enaya Capital': 1,
#  'Jungle Ventures': 1,
#  ' Venture Highway': 1,
#  ' Piton Capital': 1,
#  ' Partech Partners': 2,
#  'Rhone Capital': 1,
#  'FAW Group': 1,
#  ' Tus Holdings': 1,
#  'Goldman Sachs': 4,
#  ' VebVentures': 1,
#  'Chiratae Ventures': 3,
#  ' PremjiInvest': 1,
#  'Aspect Ventures': 1,
#  ' SingTel Innov8': 1,
#  'Coatue Managemeny': 1,
#  'Warburg Pincus': 4,
#  'CRV': 3,
#  ' Kae Capital': 1,
#  ' The Rise Fund': 1,
#  ' HarbourVest Partners': 1,
#  'Soros Fund Management': 1,
#  ' Monashees+': 3,
#  ' RTP Global': 1,
#  ' Go-Ventures': 1,
#  ' China Media Group': 2,
#  ' Guangzhou Huiyin Aofeng Equity Investment Fund': 2,
#  ' Wakefield Group': 1,
#  'Info Edge': 1,
#  ' Softbank Capital': 1,
#  'T. Rowe Price': 2,
#  ' Dragoneer Investment Group': 1,
#  ' Lockheed Martin Ventures': 1,
#  ' Fidelity Investment': 2,
#  'Liberty City Ventures': 2,
#  ' RRE Ventures': 2,
#  ' Mithril Capital Management': 2,
#  ' Aspect Ventures': 1,
#  ' Flybridge Capital Partners': 1,
#  'Octopus Ventures': 1,
#  ' Munich Re Ventures': 4,
#  ' CommerzVentures': 1,
#  'Kibo Ventures': 1,
#  'IMM Investment': 1,
#  ' NXC': 1,
#  'V FUND': 1,
#  ' Green Pine Capital Partners': 2,
#  'Revolution': 1,
#  ' Caterpillar': 1,
#  'RedBird Capital Partners': 1,
#  ' CJ ENM': 1,
#  'Relay Ventures': 1,
#  ' TTV Capital': 2,
#  ' Canapi Ventures': 2,
#  'Temasek': 3,
#  ' Noshaq': 1,
#  ' Sofinnova Partners': 1,
#  ' Aglae Ventures': 1,
#  ' Alven Capital': 3,
#  'Softbank Group': 1,
#  ' AME Cloud Ventures': 2,
#  'Knox Lane': 1,
#  ' Ainge Advisory': 1,
#  ' Carlson Private Capital Partners': 1,
#  '/td>': 1,
#  ' Section 32': 1,
#  'Expa': 1,
#  'Pantera Capital': 3,
#  'Sierra Ventures': 2,
#  ' Asset Management Ventures': 1,
#  'Zhangjiang Haocheng Venture Capital': 1,
#  ' Walden International': 1,
#  'Deer Park Road': 1,
#  ' Altamont Capital Partners': 1,
#  ' Eldridge': 1,
#  ' Banyan Capital': 1,
#  '8VC': 4,
#  ' Sway Ventures': 1,
#  ' One Peak Partners': 1,
#  'Plug and Play Ventures': 1,
#  ' Valor Capital Group': 2,
#  ' Walden Venture Capital': 2,
#  ' Global Catalyst Partnera': 1,
#  ' SAIF Partners India': 1,
#  ' Valiant Capital Partners': 1,
#  'Foundation Capital': 3,
#  ' Silversmith Capital Partners': 4,
#  'VY Capital': 1,
#  'ICONIQ Growth': 1,
#  ' Sapphire Ventures': 4,
#  'GSR Ventures': 1,
#  ' Streamlined Ventures': 1,
#  ' frst': 1,
#  ' Kima Ventures': 1,
#  'L Capital Partners': 1,
#  'RRE Ventures': 1,
#  ' Tiger Global': 1,
#  ' August Capital': 1,
#  'Obvious Ventures': 1,
#  ' Matrix Partners China': 6,
#  ' 58.com': 1,
#  ' Insight Venture Partners': 1,
#  'Delphi Automotive': 1,
#  ' Motus Ventures': 1,
#  'Zheshang Venture Capital': 1,
#  ' GP Capital': 1,
#  ' Western Capital Management': 1,
#  'JD.com': 1,
#  ' Vision Plus Capital': 1,
#  'Toyota Motor Corporation': 1,
#  ' Mizuho Financial Group': 1,
#  ' FANUC': 1,
#  'Pitango Venture Capital': 1,
#  ' DFJ Growth Fund': 1,
#  ' Foundry Group': 2,
#  ' China Construction Bank': 1,
#  ' Bank of China': 1,
#  'Insight Venture Partners': 3,
#  'A&NN': 1,
#  ' Rusnano': 1,
#  ' TPG Alternative & Renewable Technologies': 1,
#  ' Ireland Strategic Investment Fund': 1,
#  'Qiming Venture Partners': 5,
#  ' Capital Today': 4,
#  ' SoftBank Group. Monashees+': 1,
#  ' Tenaya Capital': 1,
#  'Japan Post Capital': 1,
#  ' Globis Capital Partners': 1,
#  'Magma Venture Partners': 1,
#  ' Qumra Capital': 1,
#  'Bertelsmann Asia Investments': 2,
#  ' Tao Capital Partners': 2,
#  ' GF Investments': 1,
#  ' Harvey Golub Family Office': 1,
#  'Viola Ventures': 2,
#  ' Eastern Bell Capital': 1,
#  ' Hongtai Capital Holdings': 1,
#  ' World Lab Innovation': 1,
#  ' Obvious Ventures': 1,
#  'Jerusalem Venture Partners': 1,
#  ' Israel Growth Partners': 1,
#  'Tiantu Capital': 2,
#  ' CMB International Capital': 1,
#  ' Vision Knight Capital': 1,
#  'Highland Capital Partners': 2,
#  ' Oak HC/FT Partners': 2,
#  ' Emergence Capital Partners': 2,
#  ' D1 Capita Partners': 1,
#  'Tomales Bay Capital': 1,
#  ' Bain & Company': 1,
#  'Meritech Capital Partners': 1,
#  ' Spectrum Equity': 1,
#  ' Genesis Capital': 1,
#  'next47': 2,
#  ' MaC Venture Capital': 1,
#  ' FinVC': 1,
#  'Deciens Capital': 1,
#  ' Bezos Expeditions': 2,
#  ' 500 Startups': 3,
#  'ClalTech': 1,
#  ' Oryzn Capital': 1,
#  'Alta Ventures Mexico': 1,
#  ' Blue Cloud Ventures': 2,
#  'Undisclosed': 2,
#  ' Gradient Ventures': 1,
#  ' 5Y Capital': 2,
#  ' Caffeinated Capital': 4,
#  ' SciFi VC': 1,
#  ' Source Code Capital': 1,
#  ' Redpoint Ventures China': 2,
#  'Ignition Partners': 1,
#  'Rethink Impact': 1,
#  ' Work-Bench': 1,
#  'Northern Light Venture Capital': 1,
#  ' Xiaomi': 1,
#  ' FutureX Capital': 1,
#  'Vision Plus Capital': 1,
#  ' GSR Ventures': 2,
#  ' Altimeter Capital': 3,
#  ' Quiet Capital': 1,
#  'Northzone Ventures': 2,
#  ' White Star Capital': 1,
#  ' Novator Partners': 1,
#  ' Ayala Corporation': 1,
#  ' Almaz Capital Partners': 1,
#  'K9 Ventures': 1,
#  ' Menlo Ventures': 5,
#  'Gauss Ventures': 1,
#  ' Ventura Capital': 1,
#  ' dmg ventures': 1,
#  ' EQT Ventures': 1,
#  ' Paradigm': 1,
#  ' Pantera Capital': 1,
#  ' Maverick Capital': 1,
#  ' Green Innovations': 1,
#  ' Activant Capital': 2,
#  ' GLP Capital Partners': 2,
#  'Breega Capital': 1,
#  ' Iris Capital': 1,
#  ' 360 Capital Partners': 1,
#  'Trustbridge Partners': 2,
#  ' Hony Capital': 1,
#  'JTC Group': 1,
#  ' Qatar Investment Authority': 2,
#  'Square Peg Capital': 1,
#  ' TDM Growth Partners': 2,
#  'FirstMark Capital': 3,
#  'K2VC': 1,
#  ' Lightspeed China Partners': 1,
#  ' Sky9 Capital': 1,
#  ' Pelion Venture Partners': 1,
#  ' CVF Capital Partners': 1,
#  ' ARCH Venture Partners': 1,
#  'Automobile Industry Guidance Fund': 1,
#  'The Carlyle Group': 2,
#  ' CVC Capital Partners': 1,
#  ' Lowercase Capital': 2,
#  ' Polaris Partners': 1,
#  ' ClalTech': 1,
#  'YL Ventures': 1,
#  'Fashion Tech Lab': 1,
#  ' Fidelity Investments': 2,
#  ' Vast Ventures': 1,
#  'SOSV': 1,
#  'Jiangsu Sha Steel Group': 1,
#  ' Shanghai Puyin Industry': 1,
#  ' Funa Yuanchuang Technology': 1,
#  'Blumberg Capital': 1,
#  ' BDC Venture Capital': 1,
#  ' Eleation Capital': 1,
#  ' Avenir Growth Capital': 1,
#  ' QiMing Venture Partners': 1,
#  ' Chengwei Capital': 1,
#  'Tao Capital Partners': 1,
#  ' Global Asset Capital': 1,
#  'MMC Ventures': 1,
#  ' BGF Ventures': 1,
#  ' Unilever Ventures': 1,
#  ' Alkeon Capital Management': 2,
#  'Eurazeo': 1,
#  ' Balderton Capital': 4,
#  'Alta Partners': 2,
#  ' Questa Capital': 1,
#  ' Echo Health Venturesl': 1,
#  ' Baseline Ventures': 1,
#  ' Harrison Metal': 1,
#  'Gobi Partners': 1,
#  ' Ondine Capital': 1,
#  'Stripe': 1,
#  'DataTribe': 1,
#  ' Energy Impact Partners': 1,
#  ' AllegisCyber Capital': 1,
#  'Crosslink Capital': 2,
#  ' .406 Ventures': 1,
#  ' Transamerica Ventures': 1,
#  ' Crane Venture Partners': 1,
#  ' Geekdom Fund': 1,
#  ' Portag3 Ventures': 1,
#  'Salesforce Ventures': 2,
#  ' Seedcamp': 1,
#  'Yabeo Capital': 1,
#  ' Vulcan Capital': 1,
#  ' Eight Roads Ventures': 2,
#  'Carsales': 1,
#  'Boxin Capital': 1,
#  ' DT Capital Partners': 1,
#  ' Jove Equity Partners': 1,
#  'Alpha Wave Global': 1,
#  'Cybernaut Growth Fund': 1,
#  'TPG Growth': 1,
#  'GAM Holding': 1,
#  'People Electrical Appliance Group China': 1,
#  ' Zhongrong International Trust': 1,
#  ' Launchpad Venture Group': 1,
#  ' L Catterton': 1,
#  'OMERS Private Equity': 1,
#  'Blackbird Ventures': 1,
#  ' IndexVentures': 1,
#  'GreatPoint Ventures': 2,
#  ' Meritech Capital Partners': 2,
#  'March Capital Partners': 2,
#  ' HOF Capital': 1,
#  ' Aker': 1,
#  'BEENEXT': 1,
#  ' World Innovation Lab': 1,
#  ' Light Street Capital': 1,
#  ' Clocktower Technology Ventures': 2,
#  ' TI Platform Management': 1,
#  'QED Investors': 2,
#  'IFC': 1,
#  ' Ajinomoto': 1,
#  'Guozhong Venture Capital Management': 1,
#  ' Oriental Fortune Capital': 1,
#  'Centurium Capital': 1,
#  ' Cedarlake Capital': 1,
#  ' Unicom Innovation Venture Capital': 2,
#  'China Creation Ventures': 1,
#  ' Sierra Ventures': 1,
#  ' Xingwang Investment Management': 1,
#  'Co-Stone Venture Capital': 1,
#  ' Buhuo Venture Capital': 1,
#  ' QiMing Venture Partnersl': 1,
#  ' Aviation Industry Corporation of China': 1,
#  'Volkswagen': 1,
#  ' Access Industries': 2,
#  ' Vostok New Ventures': 1,
#  ' China Everbright Investment Management': 1,
#  ' Yinxinggu Capital': 1,
#  ' JOY Capital': 1,
#  'Legend Capital': 1,
#  ' CDH Investments': 2,
#  'Source Code Capital': 4,
#  ' Meituan Dianping': 2,
#  ' Madrone Capital Partners': 1,
#  'Max Ventures': 1,
#  ' Mangrove Capital Partners': 1,
#  ' 14W': 2,
#  'Rubicon Technology Partners': 1,
#  ' Max Ventures': 1,
#  ' Inclusive Capital Partners': 1,
#  'Moonshots Capital': 1,
#  ' BoxGroup': 1,
#  ' Blu Venture Investors': 1,
#  ' Shea Ventures': 2,
#  'Smilegate Investment': 1,
#  ' DSC Investments': 1,
#  ' KTB Ventures': 1,
#  'Digital Currency Group': 1,
#  ' Draper Esprit': 2,
#  ' Korelya Capital': 1,
#  'Amiti Ventures': 1,
#  ' Playground Global': 1,
#  ' Amplify Partners': 1,
#  ' Providence Equity Partners': 2,
#  ' Rembrandt Venture Partners': 1,
#  ' SOSV': 1,
#  'Felicis Ventures': 1,
#  'Fifty Years Fund': 1,
#  ' Refactor Capital': 1,
#  'VGames': 1,
#  ' Galaxy Interactive': 2,
#  'Scale Venture Partners': 2,
#  ' Wonder Ventures': 1,
#  'Ant Group': 1,
#  ' Charoen Pokphand Group': 1,
#  ' Bow Wave Capital': 1,
#  'Spark Capital': 2,
#  ' CRE Venture Capital': 2,
#  'Nyca Partners': 1,
#  'Accomplice': 3,
#  ' Polychain Capital': 2,
#  ' GoldenTree Asset Management': 1,
#  ' Connect Ventures': 2,
#  ' Kibo Ventures': 1,
#  'PSG': 1,
#  ' ION Crossover Partners': 1,
#  'Redpoint e.ventures': 1,
#  ' SoftBank Latin America Fund': 1,
#  ' SV Angel': 1,
#  'Brighton Park Capital': 1,
#  ' Workday Ventures': 1,
#  'Samsung Ventures': 1,
#  ' SingulariTeam': 1,
#  ' BP Ventures': 1,
#  'L Catterton': 1,
#  ' First Light Capital Group': 1,
#  ' Human Capital': 1,
#  'Eastern Bell Capital': 3,
#  ' Longzhu Capital': 1,
#  ' CSC Group': 1,
#  'Baidu': 1,
#  'Ding Xiang Capital': 1,
#  ' New Hope Fund': 1,
#  ' Sino-Ocean Capital': 1,
#  'Taigang Venture Capital': 1,
#  'Sodexo Ventures': 1,
#  'Left Lane Capital': 3,
#  ' BUILD Capital Partners': 1,
#  'Kickstart Fund': 1,
#  ' Drive Capital': 1,
#  ' Tiger Global management': 2,
#  'BNP Paribas': 1,
#  'Phoenix New Media': 1,
#  ' Tianjin Haihe Industry Fund': 1,
#  'Seaya Ventures': 1,
#  ' Otter Rock Capital': 1,
#  ' Rakuten': 1,
#  ' SF Holding Co': 1,
#  ' STO Express': 1,
#  'Orange Digital Ventures': 1,
#  ' Entree Capital': 1,
#  ' Blumberg Capital': 2,
#  ' AXA Venture Partners': 1,
#  ' Sigma Prime Ventures': 1,
#  'Helion Venture Partners': 2,
#  'Signal Peak Ventures': 1,
#  ' Owl Ventures': 1,
#  'Refactor Capital': 1,
#  ' Fifty Years Fund': 1,
#  ' Tengelmann Ventures': 1,
#  ' Holtzbrinck Ventures': 1,
#  ' Lightbox Ventures': 1,
#  'Simon Equity Partners': 1,
#  ' Wavemaker Partners': 1,
#  ' Anthem Venture Partners': 1,
#  'Innovation Endeavors': 2,
#  ' s28 Capital': 1,
#  ' Hummingbird Ventures': 1,
#  ' Epiq Capital': 1,
#  'Bonfire Ventures': 1,
#  ' FJ Labs': 2,
#  ' Initialized Capital': 2,
#  ' TriplePoint Capital': 2,
#  'Newion Partners': 1,
#  ' SmartFin Capital': 1,
#  ' Doha Venture Capital': 1,
#  'TLV Partners': 2,
#  ' Qatar Holding': 1,
#  'DESUN Capital': 1,
#  ' Meridian Capital': 1,
#  'Green Pine Capital Partners': 1,
#  ' Ivy Capital': 1,
#  ' Resolute Ventures': 1,
#  'Marchmont Ventures': 1,
#  ' BMW i Ventures': 2,
#  'Advantech Capital': 1,
#  ' Temasek Holdings Ltd.': 1,
#  ' Tiantu Capital Co.': 1,
#  'MHS Capital': 1,
#  ' NextView Ventures': 1,
#  ' Mayfield Fund': 1,
#  'SC.Holdings': 1,
#  ' Not Boring Capital': 1,
#  ' Bolt Ventures': 1,
#  'ARCH Venture Partners': 1,
#  ' Ally Bridge Group': 1,
#  'BlueCross BlueShield Venture Partners': 1,
#  ' US Venture Partners': 1,
#  'Hopu Investment Management': 1,
#  ' DC Thomson Ventures': 1,
#  'York Capital Management': 1,
#  ' GE Healthcare': 1,
#  ' Koch Disruptive Technologies': 1,
#  ' Next Coast Ventures': 1,
#  ' SoGal Ventures': 1,
#  ' H Capital': 1,
#  'N5 Capital': 1,
#  ' CR Capital Mgmt': 1,
#  ' JD Digits': 1,
#  'SWaN & Legend Ventures': 1,
#  ' Invus Group': 1,
#  ' Spotify': 1,
#  ' Anthermis': 1,
#  ' International Finance Corporation': 2,
#  'SignalFire': 1,
#  ' Wipro Ventures': 1,
#  'LocalGlobe': 2,
#  ' Soros Fund Management': 1,
#  ' Summer Capital': 1,
#  ' Kraken Ventures': 1,
#  ' GSV Ventures': 2,
#  'Chromo Invest': 1,
#  ' Maersk Growth': 1,
#  'Social Capital': 1,
#  'Mitsubishi Corporation': 1,
#  ' Mayfair Equity Partners': 1,
#  ' Gaocheng Capital': 1,
#  ' Chuanrong Capital': 1,
#  'Dark Horse Technology Group': 1,
#  ' Hopu Investment Management': 1,
#  ' Kefa Capital': 1,
#  ' CMC Capital Partners': 1,
#  ...}

# %%
data_items = my_dict.items()
data_list = list(data_items)
#data_list
df_2 = pd. DataFrame(data_list) 
print(df_2)
# Out:
#             Company  Valuation Date_Added        Country  \
# 0         Bytedance      140.0 2017-04-07          China
# 1            SpaceX      100.3 2012-12-01  United States
# 2            Stripe       95.0 2014-01-23  United States
# 3            Klarna       45.6 2011-12-12         Sweden
# 4        Epic Games       42.0 2018-10-26  United States
# ..              ...        ...        ...            ...
# 995      Fever Labs        1.0 2022-01-26  United States
# 996           Minio        1.0 2022-01-26  United States
# 997           Esusu        1.0 2022-01-27  United States
# 998       Betterfly        1.0 2022-02-01          Chile
# 999  Dune Analytics        1.0 2022-02-02         Norway
#
#                          Category  \
# 0         Artificial intelligence
# 1                           Other
# 2                         Fintech
# 3                         Fintech
# 4                           Other
# ..                            ...
# 995  Internet software & services
# 996   Data management & analytics
# 997                       Fintech
# 998       Artificial intelligence
# 999   Data management & analytics
#
#                                       Select Investors
# 0    Sequoia Capital China, SIG Asia Investments, S...
# 1    Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2          Khosla Ventures, LowercaseCapital, capitalG
# 3    Institutional Venture Partners, Sequoia Capita...
# 4                Tencent Holdings, KKR, Smash Ventures
# ..                                                 ...
# 995                              Accel, 14W, GS Growth
# 996  General Catalyst, Nexus Venture Partners, Dell...
# 997  Next Play Ventures, Zeal Capital Partners, Sof...
# 998                QED Investors, DST Global, Endeavor
# 999  Multicoin Capital, Coatue Management, Dragonfl...
#
# [1000 rows x 6 columns]

# %%
df_2.head()
# Out:
#                        0   1
# 0  Sequoia Capital China  29
# 1   SIG Asia Investments   3
# 2             Sina Weibo   2
# 3         Softbank Group   8
# 4          Founders Fund   4

# %%
df_2.rename(columns={0: "Investors", 1: "count"}, inplace=True)

# %%
df_2.count
# Out:
# <bound method DataFrame.count of                         Investors  count
# 0           Sequoia Capital China     29
# 1            SIG Asia Investments      3
# 2                      Sina Weibo      2
# 3                  Softbank Group      8
# 4                   Founders Fund      4
# ...                           ...    ...
# 1447              Endiya Partners      1
# 1448           Next Play Ventures      1
# 1449        Zeal Capital Partners      1
# 1450            Multicoin Capital      1
# 1451   Dragonfly Capital Partners      1
#
# [1452 rows x 2 columns]>

# %%
C = df_2['count']

over_20 = 0
under_20 = 0
for x in C:
    if x > 20:
        over_20 += 1
    else:
        under_20 += 1

# %%
one_time = df_2['count'] == 1

# %%
df_2[one_time]
# Out:
#                         Investors  count
# 5         Draper Fisher Jurvetson      1
# 6             Rothenberg Ventures      1
# 8                LowercaseCapital      1
# 15                 Smash Ventures      1
# 22             Collaborative Fund      1
# ...                           ...    ...
# 1447              Endiya Partners      1
# 1448           Next Play Ventures      1
# 1449        Zeal Capital Partners      1
# 1450            Multicoin Capital      1
# 1451   Dragonfly Capital Partners      1
#
# [1056 rows x 2 columns]

# %%
df_2['count'].unique()
# Out:
# array([29,  3,  2,  8,  4,  1, 11,  6, 27, 18, 14, 21, 15, 25,  7, 13, 16,
#        17, 12,  5, 10, 30, 23, 19, 33,  9, 20])

# %%
inv = df_2.sort_values(by='count', ascending=False)

# %%
inv.head()
# Out:
#                     Investors  count
# 163   Tiger Global Management     33
# 122                     Accel     30
# 0       Sequoia Capital China     29
# 11            Sequoia Capital     27
# 45                      Accel     27

# %%
inv.describe()
# Out:
#              count
# count  1452.000000
# mean      1.951102
# std       2.922798
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max      33.000000

# %%
df_2.iloc[163,:]
# Out:
# Investors     Tiger Global Management
# count                              33
# Name: 163, dtype: object

# %%
"""df_2.to_excel('investors.xlsx')"""
# Out:
# "df_2.to_excel('investors.xlsx')"

# %%
'''inv.to_excel('ordered_investors.xlsx')'''

# %%
"""df.to_excel('df.xlsx')"""
# Out:
# "df.to_excel('df.xlsx')"

# %%
contain_values = df[df['Investors_by_company'].str.contains('Tiger Global Management')]
contain_values.head(5)
# Out:
#          Company  Valuation Date_Added         Country  \
# 6   Checkout.com       40.0 2019-05-02  United Kingdom
# 19         SHEIN       15.0 2018-07-03           China
# 29     JUUL Labs       12.0 2017-12-20   United States
# 74      Razorpay        7.5 2020-10-11           India
# 75         Getir        7.5 2021-03-26          Turkey
#
#                            Category  \
# 6                           Fintech
# 19  E-commerce & direct-to-consumer
# 29                Consumer & retail
# 74                          Fintech
# 75  E-commerce & direct-to-consumer
#
#                                  Investors_by_company
# 6   Tiger Global Management, Insight Partners, DST...
# 19  Tiger Global Management, Sequoia Capital China...
# 29                            Tiger Global Management
# 74  Sequoia Capital India, Tiger Global Management...
# 75  Tiger Global Management, Sequoia Capital, Revo...

# %% [markdown]
# Plotting countries that have been mentionned the most

# %%
Country = (df['Country'].str.count(',')
                      .add(1)
                      .groupby(df.Country)
                      .sum().sort_values(ascending=False))

# %%
Country.plot(kind='bar')
plt.title('countries where Tiger Global Management invested')
plt.xlabel('countries')
plt.ylabel('Number of companies')
# Out:
# Text(0, 0.5, 'Number of companies')

# %% [markdown]
# # Investors in USA

# %%
Usa = df[df['Country'].str.contains('U')]

# %%
v = contain_values['Category'].value_counts()

# %%
p.plot(kind='bar')
plt.title('countries where Tiger Global Management invested')
plt.xlabel('countries')
plt.ylabel('Number of investments')
# Out:
# Text(0, 0.5, 'Number of investments')

# %%
v.plot(kind='bar')
plt.title('fields where Tiger Global Management invested')
plt.xlabel('fileds')
plt.ylabel('Number of investments')
# Out:
# Text(0, 0.5, 'Number of investments')

# %%
df['Country'].value_counts()

# %% [markdown]
# # Exploratory analyses
#
# df = la base de donnée comme elle est
#
# df_2 = dataframe ou j'ai compter les investisseur

# %% [markdown]
# -

# %%
inv.reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/tm/ym72fqh16_7by4fpzh7vcv_80000gn/T/ipykernel_884/3568948576.py in <module>
# ----> 1 inv.reset_index()
#       2 inv
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5797                     )
#    5798
# -> 5799                 new_obj.insert(0, name, level_values)
#    5800
#    5801         new_obj.index = new_index
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4412         if not allow_duplicates and column in self.columns:
#    4413             # Should this be a different kind of error??
# -> 4414             raise ValueError(f"cannot insert {column}, already exists")
#    4415         if not isinstance(loc, int):
#    4416             raise TypeError("loc must be int")
#
# ValueError: cannot insert level_0, already exists

# %%
inv
# Out:
#       level_0  index                    Investors  count
# 0           0    163      Tiger Global Management     33
# 1           1    122                        Accel     30
# 2           2      0        Sequoia Capital China     29
# 3           3     11              Sequoia Capital     27
# 4           4     45                        Accel     27
# ...       ...    ...                          ...    ...
# 1447     1447    671        Vision Knight Capital      1
# 1448     1448    675           D1 Capita Partners      1
# 1449     1449    676          Tomales Bay Capital      1
# 1450     1450    677               Bain & Company      1
# 1451     1451   1451   Dragonfly Capital Partners      1
#
# [1452 rows x 4 columns]

# %%
ten_inv = inv.loc[:10,'Investors':]

# %%
ten_inv.plot(kind='bar', x='Investors')
# Out:
# <AxesSubplot:xlabel='Investors'>

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.barh(ten_inv['Investors'], ten_inv['count'])
# Out:
# <BarContainer object of 11 artists>
